# %%
import requests
from requests.auth import HTTPBasicAuth
import pandas as pd
import json

# URL base da API
base_url = "http://18.209.218.63:8080"

# (🔁 atualize o endpoint depois de descobrir o correto)
endpoint = "/"

# Requisição com autenticação básica
response = requests.get(base_url + endpoint, auth=HTTPBasicAuth("USUÁRIO", "SENHA"))

# Verifica status e estrutura
print("Status code:", response.status_code)
try:
    data = response.json()
    print(json.dumps(data, indent=2))  # Visualiza os dados
except Exception as e:
    print("Erro ao converter para JSON:", e)
    print("Resposta bruta:", response.text)
# Out:
# Status code: 200
# Erro ao converter para JSON: Expecting value: line 2 column 5 (char 5)
# Resposta bruta:
#     <!DOCTYPE html>
#     <html>
#     <head>
#     <link type="text/css" rel="stylesheet" href="https://cdn.jsdelivr.net/npm/swagger-ui-dist@5.9.0/swagger-ui.css">
#     <link rel="shortcut icon" href="https://fastapi.tiangolo.com/img/favicon.png">
#     <title>Adventure Works integration API - Swagger UI</title>
#     </head>
#     <body>
#     <div id="swagger-ui">
#     </div>
#     <script src="https://cdn.jsdelivr.net/npm/swagger-ui-dist@5.9.0/swagger-ui-bundle.js"></script>
#     <!-- `SwaggerUIBundle` is now available on the page -->
#     <script>
#     const ui = SwaggerUIBundle({
#         url: '/openapi.json',
#     "dom_id": "#swagger-ui",
# "layout": "BaseLayout",
# "deepLinking": true,
# "showExtensions": true,
# "showCommonExtensions": true,
# oauth2RedirectUrl: window.location.origin + '/docs/oauth2-redirect',
#     presets: [
# ...

# %%
url = "http://18.209.218.63:8080/openapi.json"

response = requests.get(url, auth=HTTPBasicAuth("admin", "Lh042025"))
print(response.status_code)

try:
    openapi_doc = response.json()
    print(openapi_doc.keys())
except Exception as e:
    print("Erro ao processar o Swagger JSON:", e)
    print(response.text[:500])
# Out:
# 200
# dict_keys(['openapi', 'info', 'paths', 'components'])

# %%
for path in openapi_doc["paths"]:
    print(path)
# Out:
# /SalesOrderDetail
# /SalesOrderHeader
# /PurchaseOrderDetail
# /PurchaseOrderHeader
# /

# %%
import requests
from requests.auth import HTTPBasicAuth
import pandas as pd
import json

endpoint = "/SalesOrderHeader"
base_url = "http://18.209.218.63:8080"
url = base_url + endpoint

# Requisição
response = requests.get(url, auth=HTTPBasicAuth("admin", "Lh042025"))

# Validar e transformar em JSON
print("Status:", response.status_code)
data_1 = response.json()
# Out:
# Status: 200

# %%
try:
    data_items_1 = list(data_1.items())
    print(json.dumps(data_items_1[:2], indent=2))
except Exception as e:
    print(f"Erro ao tentar mostrar os dois primeiros itens: {e}")

df_1 = pd.DataFrame(data_items_1)
df_1.head()
# Out:
# [
#   [
#     "total",
#     31465
#   ],
#   [
#     "offset",
#     0
#   ]
# ]
#         0                                                  1
# 0   total                                              31465
# 1  offset                                                  0
# 2   limit                                                 10
# 3    data  [{'SalesOrderID': 43659, 'RevisionNumber': 8, ...

# %%
df_1.head()
# Out:
#         0                                                  1
# 0   total                                              31465
# 1  offset                                                  0
# 2   limit                                                 10
# 3    data  [{'SalesOrderID': 43659, 'RevisionNumber': 8, ...

# %%
# Validar e transformar em JSON
print("Status:", response.status_code)
data_1 = response.json()

df_1 = pd.DataFrame(data_1)

df_exploded = df_1['data'].apply(pd.Series)


control_cols = [col for col in ['total', 'offset', 'limit'] if col in df_1.columns]
df_final_1 = pd.concat([df_1[control_cols], df_exploded], axis=1)


df_final_1.head(100)
# Out:
# Status: 200
#    total  offset  limit  SalesOrderID  RevisionNumber            OrderDate  \
# 0  31465       0     10         43659               8  2011-05-31T00:00:00
# 1  31465       0     10         43660               8  2011-05-31T00:00:00
# 2  31465       0     10         43661               8  2011-05-31T00:00:00
# 3  31465       0     10         43662               8  2011-05-31T00:00:00
# 4  31465       0     10         43663               8  2011-05-31T00:00:00
# 5  31465       0     10         43664               8  2011-05-31T00:00:00
# 6  31465       0     10         43665               8  2011-05-31T00:00:00
# 7  31465       0     10         43666               8  2011-05-31T00:00:00
# 8  31465       0     10         43667               8  2011-05-31T00:00:00
# 9  31465       0     10         43668               8  2011-05-31T00:00:00
#
#                DueDate  Status  OnlineOrderFlag SalesOrderNumber  ...  \
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4 non-null      object
#  1   1       4 non-null      object
# dtypes: object(2)
# memory usage: 196.0+ bytes

# %%
endpoint = "/SalesOrderDetail"
base_url = "http://18.209.218.63:8080"
url = base_url + endpoint

# Requisição
response_2 = requests.get(url, auth=HTTPBasicAuth("admin", "Lh042025"))

# Validar e transformar em JSON
print("Status:", response_2.status_code)
data_2 = response_2.json()
# Out:
# Status: 200

# %%
endpoint = "/PurchaseOrderDetail"
base_url = "http://18.209.218.63:8080"
url = base_url + endpoint

# Requisição
response_3 = requests.get(url, auth=HTTPBasicAuth("admin", "Lh042025"))

# Validar e transformar em JSON
print("Status:", response_3.status_code)
data_3 = response_3.json()
# Out:
# Status: 200

# %%
endpoint = "/PurchaseOrderHeader"
base_url = "http://18.209.218.63:8080"
url = base_url + endpoint

# Requisição
response_4 = requests.get(url, auth=HTTPBasicAuth("admin", "Lh042025"))

# Validar e transformar em JSON
print("Status:", response_4.status_code)
data_4 = response_4.json()
# Out:
# Status: 200

# %% [markdown]
# ## TESTANDO OUTPUT DOS ENDPOINTS

# %%
# testando output /SalesOrderDetail
try:
    data_items = list(data_2.items())
    print(json.dumps(data_items[:2], indent=2))
except Exception as e:
    print(f"Erro ao tentar mostrar os dois primeiros itens: {e}")

df_2 = pd.DataFrame(data_2)
df_2.head()
# Out:
# [
#   [
#     "total",
#     121317
#   ],
#   [
#     "offset",
#     0
#   ]
# ]
#     total  offset  limit                                               data
# 0  121317       0     10  {'SalesOrderID': 43659, 'SalesOrderDetailID': ...
# 1  121317       0     10  {'SalesOrderID': 43659, 'SalesOrderDetailID': ...
# 2  121317       0     10  {'SalesOrderID': 43659, 'SalesOrderDetailID': ...
# 3  121317       0     10  {'SalesOrderID': 43659, 'SalesOrderDetailID': ...
# 4  121317       0     10  {'SalesOrderID': 43659, 'SalesOrderDetailID': ...

# %%
# Extrai os campos reais de dentro da coluna 'data'
df_exploded_2 = df_2['data'].apply(pd.Series)

# Junta com colunas de controle (opcional)
df_final_2 = pd.concat([df_2[['total', 'offset', 'limit']], df_exploded_2], axis=1)

# Verificar estrutura
df_final_2.head()
# Out:
#     total  offset  limit  SalesOrderID  SalesOrderDetailID  OrderQty  \
# 0  121317       0     10         43659                   1         1
# 1  121317       0     10         43659                   2         3
# 2  121317       0     10         43659                   3         1
# 3  121317       0     10         43659                   4         1
# 4  121317       0     10         43659                   5         1
#
#    ProductID  SpecialOfferID  UnitPrice  UnitPriceDiscount  LineTotal  \
# 0        776               1   2024.994                0.0   2024.994
# 1        777               1   2024.994                0.0   6074.982
# 2        778               1   2024.994                0.0   2024.994
# 3        771               1   2039.994                0.0   2039.994
# 4        772               1   2039.994                0.0   2039.994
#
#                                 rowguid         ModifiedDate  \
# 0  b207c96d-d9e6-402b-8470-2cc176c42283  2011-05-31T00:00:00
# ...

# %%
df_final_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   total                  10 non-null     int64
#  1   offset                 10 non-null     int64
#  2   limit                  10 non-null     int64
#  3   SalesOrderID           10 non-null     int64
#  4   SalesOrderDetailID     10 non-null     int64
#  5   OrderQty               10 non-null     int64
#  6   ProductID              10 non-null     int64
#  7   SpecialOfferID         10 non-null     int64
#  8   UnitPrice              10 non-null     float64
#  9   UnitPriceDiscount      10 non-null     float64
#  10  LineTotal              10 non-null     float64
#  11  rowguid                10 non-null     object
#  12  ModifiedDate           10 non-null     object
#  13  CarrierTrackingNumber  10 non-null     object
# dtypes: float64(3), int64(8), object(3)
# ...

# %%
# testando output /SalesOrderDetail
try:
    data_items = list(data_3.items())
    print(json.dumps(data_items[:2], indent=2))
except Exception as e:
    print(f"Erro ao tentar mostrar os dois primeiros itens: {e}")

df_3 = pd.DataFrame(data_3)
df_3.head()
# Out:
# [
#   [
#     "total",
#     8845
#   ],
#   [
#     "offset",
#     0
#   ]
# ]
#    total  offset  limit                                               data
# 0   8845       0     10  {'PurchaseOrderID': 1, 'PurchaseOrderDetailID'...
# 1   8845       0     10  {'PurchaseOrderID': 2, 'PurchaseOrderDetailID'...
# 2   8845       0     10  {'PurchaseOrderID': 2, 'PurchaseOrderDetailID'...
# 3   8845       0     10  {'PurchaseOrderID': 3, 'PurchaseOrderDetailID'...
# 4   8845       0     10  {'PurchaseOrderID': 4, 'PurchaseOrderDetailID'...

# %%
# Extrai os campos reais de dentro da coluna 'data'
df_exploded_3 = df_3['data'].apply(pd.Series)

# Junta com colunas de controle (opcional)
df_final_3 = pd.concat([df_3[['total', 'offset', 'limit']], df_exploded_3], axis=1)

# Verificar estrutura
df_final_3.head(15)
# Out:
#    total  offset  limit  PurchaseOrderID  PurchaseOrderDetailID  \
# 0   8845       0     10                1                      1
# 1   8845       0     10                2                      2
# 2   8845       0     10                2                      3
# 3   8845       0     10                3                      4
# 4   8845       0     10                4                      5
# 5   8845       0     10                5                      6
# 6   8845       0     10                6                      7
# 7   8845       0     10                7                      8
# 8   8845       0     10                7                      9
# 9   8845       0     10                7                     10
#
#                DueDate  OrderQty  ProductID  UnitPrice   LineTotal  \
# 0  2011-04-30T00:00:00         4          1    50.2600    201.0400
# 1  2011-04-30T00:00:00         3        359    45.1200    135.3600
# ...

# %%
df_final_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   total                  10 non-null     int64
#  1   offset                 10 non-null     int64
#  2   limit                  10 non-null     int64
#  3   PurchaseOrderID        10 non-null     int64
#  4   PurchaseOrderDetailID  10 non-null     int64
#  5   DueDate                10 non-null     object
#  6   OrderQty               10 non-null     int64
#  7   ProductID              10 non-null     int64
#  8   UnitPrice              10 non-null     float64
#  9   LineTotal              10 non-null     float64
#  10  ReceivedQty            10 non-null     float64
#  11  RejectedQty            10 non-null     float64
#  12  StockedQty             10 non-null     float64
#  13  ModifiedDate           10 non-null     object
# dtypes: float64(5), int64(7), object(2)
# ...

# %%
try:
    data_items = list(data_4.items())
    print(json.dumps(data_items[:2], indent=2))
except Exception as e:
    print(f"Erro ao tentar mostrar os dois primeiros itens: {e}")

df_4 = pd.DataFrame(data_4)
df_4.head(15)
# Out:
# [
#   [
#     "total",
#     4012
#   ],
#   [
#     "offset",
#     0
#   ]
# ]
#    total  offset  limit                                               data
# 0   4012       0     10  {'PurchaseOrderID': 1, 'RevisionNumber': 4, 'S...
# 1   4012       0     10  {'PurchaseOrderID': 2, 'RevisionNumber': 4, 'S...
# 2   4012       0     10  {'PurchaseOrderID': 3, 'RevisionNumber': 4, 'S...
# 3   4012       0     10  {'PurchaseOrderID': 4, 'RevisionNumber': 4, 'S...
# 4   4012       0     10  {'PurchaseOrderID': 5, 'RevisionNumber': 4, 'S...
# 5   4012       0     10  {'PurchaseOrderID': 6, 'RevisionNumber': 4, 'S...
# 6   4012       0     10  {'PurchaseOrderID': 7, 'RevisionNumber': 4, 'S...
# 7   4012       0     10  {'PurchaseOrderID': 8, 'RevisionNumber': 4, 'S...
# 8   4012       0     10  {'PurchaseOrderID': 9, 'RevisionNumber': 5, 'S...
# 9   4012       0     10  {'PurchaseOrderID': 10, 'RevisionNumber': 4, '...

# %%
# Extrai os campos reais de dentro da coluna 'data'
df_exploded_4 = df_4['data'].apply(pd.Series)

# Junta com colunas de controle (opcional)
df_final_4 = pd.concat([df_4[['total', 'offset', 'limit']], df_exploded_4], axis=1)

# Verificar estrutura
df_final_4.head()
# Out:
#    total  offset  limit  PurchaseOrderID  RevisionNumber  Status  EmployeeID  \
# 0   4012       0     10                1               4       4         258
# 1   4012       0     10                2               4       1         254
# 2   4012       0     10                3               4       4         257
# 3   4012       0     10                4               4       3         261
# 4   4012       0     10                5               4       4         251
#
#    VendorID  ShipMethodID            OrderDate    SubTotal     TaxAmt  \
# 0      1580             3  2011-04-16T00:00:00    201.0400    16.0832
# 1      1496             5  2011-04-16T00:00:00    272.1015    21.7681
# 2      1494             2  2011-04-16T00:00:00   8847.3000   707.7840
# 3      1650             5  2011-04-16T00:00:00    171.0765    13.6861
# 4      1654             4  2011-04-30T00:00:00  20397.3000  1631.7840
#
#     Freight    TotalDue         ModifiedDate             ShipDate
# ...

# %%
df_final_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   total            10 non-null     int64
#  1   offset           10 non-null     int64
#  2   limit            10 non-null     int64
#  3   PurchaseOrderID  10 non-null     int64
#  4   RevisionNumber   10 non-null     int64
#  5   Status           10 non-null     int64
#  6   EmployeeID       10 non-null     int64
#  7   VendorID         10 non-null     int64
#  8   ShipMethodID     10 non-null     int64
#  9   OrderDate        10 non-null     object
#  10  SubTotal         10 non-null     float64
#  11  TaxAmt           10 non-null     float64
#  12  Freight          10 non-null     float64
#  13  TotalDue         10 non-null     float64
#  14  ModifiedDate     10 non-null     object
#  15  ShipDate         10 non-null     object
# dtypes: float64(4), int64(9), object(3)
# ...
