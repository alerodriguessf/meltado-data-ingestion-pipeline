# %%
# %python
# Databricks notebook source
# MAGIC %md
# MAGIC ## Ingestão de Parquet do SQL Server para Delta Lake
# MAGIC Este notebook percorre os diretórios de origem contendo arquivos Parquet exportados do SQL Server e converte cada diretório em uma tabela Delta gerenciada no Databricks com prefixo `raw_sqlserver_`.

# COMMAND ----------
# 🧱 BLOCO 1 - Configurações
catalog = "ted_dev"
schema = "dev_alexandre_filho"
caminho_raw = "/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/"

# COMMAND ----------
# 🧱 BLOCO 2 - Função para normalizar nomes de tabelas
import re

def normalizar_nome_tabela(caminho):
    # Extrai nome do diretório
    nome = caminho.rstrip("/").split("/")[-1]
    nome_normalizado = re.sub(r"[^a-zA-Z0-9]", "_", nome).lower()
    if nome_normalizado:
        return f"raw_sqlserver_{nome_normalizado}_db"
    return None

# COMMAND ----------
# 🧱 BLOCO 3 - Função para criar tabela Delta

def criar_tabela_delta(caminho_base):
    nome_tabela = normalizar_nome_tabela(caminho_base)
    if not nome_tabela:
        print(f"❌ Nome inválido para: {caminho_base}")
        return

    # Buscar arquivos parquet
    arquivos_parquet = dbutils.fs.ls(caminho_base)
    arquivos_validos = [f.path for f in arquivos_parquet if f.path.endswith(".parquet") or f.path.endswith(".gz.parquet")]

    if not arquivos_validos:
        for subdir in arquivos_parquet:
            if subdir.isDir():
                sub_arquivos = dbutils.fs.ls(subdir.path)
                arquivos_validos += [f.path for f in sub_arquivos if f.path.endswith(".parquet") or f.path.endswith(".gz.parquet")]

    if not arquivos_validos:
        print(f"⚠️ Nenhum arquivo Parquet encontrado em: {caminho_base}")
        return

    print(f"📦 Lendo arquivos: {arquivos_validos[:1]} ... (total: {len(arquivos_validos)})")
    df = spark.read.format("parquet").load(arquivos_validos)

    # Renomear colunas inválidas
    for col in df.columns:
        new_col = re.sub(r"[ ,;{}()\n\t=]", "_", col)
        df = df.withColumnRenamed(col, new_col)

    df.write.format("delta") \
      .mode("overwrite") \
      .saveAsTable(f"{catalog}.{schema}.{nome_tabela}")

    print(f"✅ Tabela {catalog}.{schema}.{nome_tabela} criada com sucesso!")

# COMMAND ----------
# 🧱 BLOCO 4 - Execução para cada subdiretório
subpastas = dbutils.fs.ls(caminho_raw)

for pasta in subpastas:
    if pasta.isDir():
        criar_tabela_delta(pasta.path)
# Out:
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/HumanResources-Department/HumanResources-Department-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_humanresources_department_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/HumanResources-Employee/HumanResources-Employee-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_humanresources_employee_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/HumanResources-EmployeeDepartmentHistory/HumanResources-EmployeeDepartmentHistory-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_humanresources_employeedepartmenthistory_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/HumanResources-EmployeePayHistory/HumanResources-EmployeePayHistory-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_humanresources_employeepayhistory_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/HumanResources-JobCandidate/HumanResources-JobCandidate-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_humanresources_jobcandidate_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/HumanResources-Shift/HumanResources-Shift-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_humanresources_shift_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/HumanResources-vEmployee/HumanResources-vEmployee-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_humanresources_vemployee_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/HumanResources-vEmployeeDepartment/HumanResources-vEmployeeDepartment-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_humanresources_vemployeedepartment_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/HumanResources-vEmployeeDepartmentHistory/HumanResources-vEmployeeDepartmentHistory-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_humanresources_vemployeedepartmenthistory_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/HumanResources-vJobCandidate/HumanResources-vJobCandidate-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_humanresources_vjobcandidate_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/HumanResources-vJobCandidateEducation/HumanResources-vJobCandidateEducation-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_humanresources_vjobcandidateeducation_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/HumanResources-vJobCandidateEmployment/HumanResources-vJobCandidateEmployment-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_humanresources_vjobcandidateemployment_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Person-Address/Person-Address-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_person_address_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Person-AddressType/Person-AddressType-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_person_addresstype_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Person-BusinessEntity/Person-BusinessEntity-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_person_businessentity_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Person-BusinessEntityAddress/Person-BusinessEntityAddress-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_person_businessentityaddress_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Person-BusinessEntityContact/Person-BusinessEntityContact-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_person_businessentitycontact_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Person-ContactType/Person-ContactType-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_person_contacttype_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Person-CountryRegion/Person-CountryRegion-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_person_countryregion_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Person-EmailAddress/Person-EmailAddress-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_person_emailaddress_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Person-Password/Person-Password-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_person_password_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Person-Person/Person-Person-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_person_person_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Person-PersonPhone/Person-PersonPhone-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_person_personphone_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Person-PhoneNumberType/Person-PhoneNumberType-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_person_phonenumbertype_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Person-StateProvince/Person-StateProvince-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_person_stateprovince_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Person-vAdditionalContactInfo/Person-vAdditionalContactInfo-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_person_vadditionalcontactinfo_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Person-vStateProvinceCountryRegion/Person-vStateProvinceCountryRegion-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_person_vstateprovincecountryregion_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-BillOfMaterials/Production-BillOfMaterials-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_billofmaterials_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-Culture/Production-Culture-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_culture_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-Document/Production-Document-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_document_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-Illustration/Production-Illustration-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_illustration_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-Location/Production-Location-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_location_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-Product/Production-Product-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_product_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-ProductCategory/Production-ProductCategory-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_productcategory_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-ProductCostHistory/Production-ProductCostHistory-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_productcosthistory_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-ProductDescription/Production-ProductDescription-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_productdescription_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-ProductDocument/Production-ProductDocument-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_productdocument_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-ProductInventory/Production-ProductInventory-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_productinventory_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-ProductListPriceHistory/Production-ProductListPriceHistory-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_productlistpricehistory_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-ProductModel/Production-ProductModel-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_productmodel_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-ProductModelIllustration/Production-ProductModelIllustration-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_productmodelillustration_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-ProductModelProductDescriptionCulture/Production-ProductModelProductDescriptionCulture-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_productmodelproductdescriptionculture_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-ProductPhoto/Production-ProductPhoto-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_productphoto_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-ProductProductPhoto/Production-ProductProductPhoto-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_productproductphoto_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-ProductReview/Production-ProductReview-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_productreview_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-ProductSubcategory/Production-ProductSubcategory-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_productsubcategory_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-ScrapReason/Production-ScrapReason-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_scrapreason_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-TransactionHistory/Production-TransactionHistory-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_transactionhistory_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-TransactionHistoryArchive/Production-TransactionHistoryArchive-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_transactionhistoryarchive_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-UnitMeasure/Production-UnitMeasure-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_unitmeasure_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-WorkOrder/Production-WorkOrder-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_workorder_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-WorkOrderRouting/Production-WorkOrderRouting-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_workorderrouting_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-vProductAndDescription/Production-vProductAndDescription-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_vproductanddescription_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-vProductModelCatalogDescription/Production-vProductModelCatalogDescription-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_vproductmodelcatalogdescription_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Production-vProductModelInstructions/Production-vProductModelInstructions-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_production_vproductmodelinstructions_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Purchasing-ProductVendor/Purchasing-ProductVendor-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_purchasing_productvendor_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Purchasing-PurchaseOrderDetail/Purchasing-PurchaseOrderDetail-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_purchasing_purchaseorderdetail_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Purchasing-PurchaseOrderHeader/Purchasing-PurchaseOrderHeader-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_purchasing_purchaseorderheader_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Purchasing-ShipMethod/Purchasing-ShipMethod-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_purchasing_shipmethod_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Purchasing-Vendor/Purchasing-Vendor-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_purchasing_vendor_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Purchasing-vVendorWithAddresses/Purchasing-vVendorWithAddresses-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_purchasing_vvendorwithaddresses_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Purchasing-vVendorWithContacts/Purchasing-vVendorWithContacts-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_purchasing_vvendorwithcontacts_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-CountryRegionCurrency/Sales-CountryRegionCurrency-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_countryregioncurrency_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-CreditCard/Sales-CreditCard-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_creditcard_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-Currency/Sales-Currency-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_currency_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-CurrencyRate/Sales-CurrencyRate-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_currencyrate_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-Customer/Sales-Customer-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_customer_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-PersonCreditCard/Sales-PersonCreditCard-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_personcreditcard_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-SalesOrderDetail/Sales-SalesOrderDetail-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_salesorderdetail_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-SalesOrderHeader/Sales-SalesOrderHeader-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_salesorderheader_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-SalesOrderHeaderSalesReason/Sales-SalesOrderHeaderSalesReason-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_salesorderheadersalesreason_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-SalesPerson/Sales-SalesPerson-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_salesperson_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-SalesPersonQuotaHistory/Sales-SalesPersonQuotaHistory-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_salespersonquotahistory_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-SalesReason/Sales-SalesReason-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_salesreason_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-SalesTaxRate/Sales-SalesTaxRate-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_salestaxrate_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-SalesTerritory/Sales-SalesTerritory-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_salesterritory_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-SalesTerritoryHistory/Sales-SalesTerritoryHistory-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_salesterritoryhistory_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-ShoppingCartItem/Sales-ShoppingCartItem-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_shoppingcartitem_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-SpecialOffer/Sales-SpecialOffer-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_specialoffer_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-SpecialOfferProduct/Sales-SpecialOfferProduct-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_specialofferproduct_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-Store/Sales-Store-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_store_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-vIndividualCustomer/Sales-vIndividualCustomer-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_vindividualcustomer_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-vPersonDemographics/Sales-vPersonDemographics-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_vpersondemographics_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-vSalesPerson/Sales-vSalesPerson-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_vsalesperson_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-vSalesPersonSalesByFiscalYears/Sales-vSalesPersonSalesByFiscalYears-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_vsalespersonsalesbyfiscalyears_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-vStoreWithAddresses/Sales-vStoreWithAddresses-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_vstorewithaddresses_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-vStoreWithContacts/Sales-vStoreWithContacts-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_vstorewithcontacts_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/Sales-vStoreWithDemographics/Sales-vStoreWithDemographics-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_sales_vstorewithdemographics_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/dbo-AWBuildVersion/dbo-AWBuildVersion-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_dbo_awbuildversion_db criada com sucesso!
# 📦 Lendo arquivos: ['dbfs:/Volumes/ted_dev/dev_alexandre_filho/raw/sqlserver/dbo-DatabaseLog/dbo-DatabaseLog-20250614_180707-0-0.gz.parquet'] ... (total: 1)
# ✅ Tabela ted_dev.dev_alexandre_filho.raw_sqlserver_dbo_databaselog_db criada com sucesso!
